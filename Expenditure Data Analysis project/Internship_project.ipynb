# %%
## import library that we will use in this projrct.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style # for grid stylying
# %matplotlib inline
import seaborn as sns

# %%
## Import Data From File.

# %%
data=pd.read_csv('C:\\Users\\ckkapadiya74\\Downloads\\SALESDATA.csv')
# Out:
# C:\Users\ckkapadiya74\AppData\Local\Temp\ipykernel_15768\3778900345.py:1: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv('C:\\Users\\ckkapadiya74\\Downloads\\SALESDATA.csv')

# %%
## Viwe Data.

# %%
data.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0  30-04-2017          -237.91   2017-04-30        100012.0
# 1  10002220.0  14-07-2017           368.79   2017-07-14        100233.0
# 2  10002220.0  17-10-2017           109.73   2017-10-17        116165.0
# 3  10002489.0  03-06-2017          -211.75   2017-06-03        100096.0
# 4  10004516.0  27-05-2017         96627.94   2017-05-27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  ...  Sales Cost Amount Sales Margin Amount  Sales Price  \
# ...

# %%
## Delete Unusual Columns.

# %%
del data['Unnamed: 20']
del data['Unnamed: 21']
del data['Unnamed: 22']
del data['Unnamed: 23']

# %%
## Now We Viwe  Deleted Unusual Column's Data.

# %%
data.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 0  10000481.0  30-04-2017          -237.91   2017-04-30        100012.0
# 1  10002220.0  14-07-2017           368.79   2017-07-14        100233.0
# 2  10002220.0  17-10-2017           109.73   2017-10-17        116165.0
# 3  10002489.0  03-06-2017          -211.75   2017-06-03        100096.0
# 4  10004516.0  27-05-2017         96627.94   2017-05-27        103341.0
#
#   Item Class Item Number                             Item  Line Number  \
# 0        NaN         NaN                 Urban Large Eggs       2000.0
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 3        NaN         NaN                         Kiwi Lox       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
#
#    List Price  Order Number Promised Delivery Date  Sales Amount  \
# ...

# %%
## Viwe How Manny Null Values In Each Columns.

# %%
data.isnull().sum()
# Out:
# CustKey                              253
# DateKey                              253
# Discount Amount                      255
# Invoice Date                         253
# Invoice Number                       253
# Item Class                          8542
# Item Number                          294
# Item                                 253
# Line Number                          253
# List Price                           253
# Order Number                         253
# Promised Delivery Date               253
# Sales Amount                         253
# Sales Amount Based on List Price     253
# Sales Cost Amount                    253
# Sales Margin Amount                  253
# Sales Price                          254
# Sales Quantity                       253
# Sales Rep                            253
# U/M                                  253
# dtype: int64

# %%
## Delete All The Null Value's.

# %%
data.dropna(inplace = True)

# %%
## Viwe How Manny Null Values In Each Columns.

# %%
data.isnull().sum()
# Out:
# CustKey                             0
# DateKey                             0
# Discount Amount                     0
# Invoice Date                        0
# Invoice Number                      0
# Item Class                          0
# Item Number                         0
# Item                                0
# Line Number                         0
# List Price                          0
# Order Number                        0
# Promised Delivery Date              0
# Sales Amount                        0
# Sales Amount Based on List Price    0
# Sales Cost Amount                   0
# Sales Margin Amount                 0
# Sales Price                         0
# Sales Quantity                      0
# Sales Rep                           0
# U/M                                 0
# dtype: int64

# %%
## Viwe Data Clianed From Null Values.

# %%
data.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 1  10002220.0  14-07-2017          368.790   2017-07-14        100233.0
# 2  10002220.0  17-10-2017          109.730   2017-10-17        116165.0
# 4  10004516.0  27-05-2017        96627.940   2017-05-27        103341.0
# 6  10007866.0  03-09-2017          371.014   2017-09-03        100403.0
# 7  10009356.0  18-06-2017          608.080   2017-06-18        105481.0
#
#   Item Class Item Number                             Item  Line Number  \
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
# 6        P01       20910               Moms Sliced Turkey       2000.0
# 7        P01       62550                 Tell Tale Garlic      29000.0
#
#    List Price  Order Number Promised Delivery Date  Sales Amount  \
# ...

# %%
## Rename The Column That Can be incomprehensible.

# %%
data.rename(columns ={'U/M':'Unit_of_Measure'} ,inplace=True)
data.rename(columns ={'Sales Rep':'Sales Report'} ,inplace=True)

# %%
## Add Unit of Measure's Full Name.

# %%
data['Unit_of_Measure'] = data['Unit_of_Measure'].replace("EA","Each")
data['Unit_of_Measure'] = data['Unit_of_Measure'].replace("SE","Some SI Units")
data['Unit_of_Measure'] = data['Unit_of_Measure'].replace("PR","Pair")
data.head()
# Out:
#       CustKey     DateKey  Discount Amount Invoice Date  Invoice Number  \
# 1  10002220.0  14-07-2017          368.790   2017-07-14        100233.0
# 2  10002220.0  17-10-2017          109.730   2017-10-17        116165.0
# 4  10004516.0  27-05-2017        96627.940   2017-05-27        103341.0
# 6  10007866.0  03-09-2017          371.014   2017-09-03        100403.0
# 7  10009356.0  18-06-2017          608.080   2017-06-18        105481.0
#
#   Item Class Item Number                             Item  Line Number  \
# 1        P01       20910               Moms Sliced Turkey       1000.0
# 2        P01       38076  Cutting Edge Foot-Long Hot Dogs       1000.0
# 4        P01       60776             High Top Sweet Onion       1000.0
# 6        P01       20910               Moms Sliced Turkey       2000.0
# 7        P01       62550                 Tell Tale Garlic      29000.0
#
#    List Price  Order Number Promised Delivery Date  Sales Amount  \
# ...

# %%
## Now See The Data Type Of Each Column.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56993 entries, 1 to 65281
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CustKey                           56993 non-null  float64
#  1   DateKey                           56993 non-null  object
#  2   Discount Amount                   56993 non-null  float64
#  3   Invoice Date                      56993 non-null  object
#  4   Invoice Number                    56993 non-null  float64
#  5   Item Class                        56993 non-null  object
#  6   Item Number                       56993 non-null  object
#  7   Item                              56993 non-null  object
#  8   Line Number                       56993 non-null  float64
#  9   List Price                        56993 non-null  float64
#  10  Order Number                      56993 non-null  float64
# ...

# %%
## See The All Column Name.

# %%
data.columns
# Out:
# Index(['CustKey', 'DateKey', 'Discount Amount', 'Invoice Date',
#        'Invoice Number', 'Item Class', 'Item Number', 'Item', 'Line Number',
#        'List Price', 'Order Number', 'Promised Delivery Date', 'Sales Amount',
#        'Sales Amount Based on List Price', 'Sales Cost Amount',
#        'Sales Margin Amount', 'Sales Price', 'Sales Quantity', 'Sales Report',
#        'Unit_of_Measure'],
#       dtype='object')

# %%
## Now Change The All Column Data Type.

# %%
data['CustKey'] = data['CustKey'].astype(int)
data['DateKey'] = pd.to_datetime(data['DateKey'])
data['Discount Amount'] = data['Discount Amount'].astype(int)
data['Invoice Date'] = pd.to_datetime(data['Invoice Date'])
data['Invoice Number'] = data['Invoice Number'].astype(int)
data['Line Number'] = data['Line Number'].astype(int)
data['List Price'] = data['List Price'].astype(int)
data['Order Number'] = data['Order Number'].astype(int)
data['Promised Delivery Date'] = pd.to_datetime(data['Promised Delivery Date'])
data['Sales Amount'] = data['Sales Amount'].astype(int)
data['Sales Margin Amount'] = data['Sales Margin Amount'].astype(int)
data['Sales Price'] = data['Sales Price'].astype(int)
data['Sales Quantity'] = data['Sales Quantity'].astype(int)
data['Sales Report'] = data['Sales Report'].astype(int)
data['Sales Amount Based on List Price'] = data['Sales Amount Based on List Price'].astype(int)
data['Sales Cost Amount'] = data['Sales Cost Amount'].astype(int)
# Out:
# C:\Users\ckkapadiya74\AppData\Local\Temp\ipykernel_15768\1778234297.py:2: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['DateKey'] = pd.to_datetime(data['DateKey'])
# C:\Users\ckkapadiya74\AppData\Local\Temp\ipykernel_15768\1778234297.py:9: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   data['Promised Delivery Date'] = pd.to_datetime(data['Promised Delivery Date'])

# %%
## Import re for Remove String Valu's In Item No.

# %%
import re

# %%
## Remove String Value And Change Data Type.

# %%
data['Item Number'] = data['Item Number'].apply(lambda x: re.sub(r'\D', '', str(x)))
data['Item Number'] = data['Item Number'].astype(int)

# %%
data.dtypes
# Out:
# CustKey                                      int32
# DateKey                             datetime64[ns]
# Discount Amount                              int32
# Invoice Date                        datetime64[ns]
# Invoice Number                               int32
# Item Class                                  object
# Item Number                                  int32
# Item                                        object
# Line Number                                  int32
# List Price                                   int32
# Order Number                                 int32
# Promised Delivery Date              datetime64[ns]
# Sales Amount                                 int32
# Sales Amount Based on List Price             int32
# Sales Cost Amount                            int32
# Sales Margin Amount                          int32
# Sales Price                                  int32
# Sales Quantity                               int32
# ...

# %%
data.head()
# Out:
#     CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 1  10002220 2017-07-14              368   2017-07-14          100233
# 2  10002220 2017-10-17              109   2017-10-17          116165
# 4  10004516 2017-05-27            96627   2017-05-27          103341
# 6  10007866 2017-03-09              371   2017-09-03          100403
# 7  10009356 2017-06-18              608   2017-06-18          105481
#
#   Item Class  Item Number                             Item  Line Number  \
# 1        P01        20910               Moms Sliced Turkey         1000
# 2        P01        38076  Cutting Edge Foot-Long Hot Dogs         1000
# 4        P01        60776             High Top Sweet Onion         1000
# 6        P01        20910               Moms Sliced Turkey         2000
# 7        P01        62550                 Tell Tale Garlic        29000
#
#    List Price  Order Number Promised Delivery Date  Sales Amount  \
# ...

# %%
## Add Column For Final Sales Amt.

# %%
data['final sales amount'] = data['Sales Price'] * data['Sales Quantity']
data.head()
# Out:
#     CustKey    DateKey  Discount Amount Invoice Date  Invoice Number  \
# 1  10002220 2017-07-14              368   2017-07-14          100233
# 2  10002220 2017-10-17              109   2017-10-17          116165
# 4  10004516 2017-05-27            96627   2017-05-27          103341
# 6  10007866 2017-03-09              371   2017-09-03          100403
# 7  10009356 2017-06-18              608   2017-06-18          105481
#
#   Item Class  Item Number                             Item  Line Number  \
# 1        P01        20910               Moms Sliced Turkey         1000
# 2        P01        38076  Cutting Edge Foot-Long Hot Dogs         1000
# 4        P01        60776             High Top Sweet Onion         1000
# 6        P01        20910               Moms Sliced Turkey         2000
# 7        P01        62550                 Tell Tale Garlic        29000
#
#    List Price  ...  Promised Delivery Date Sales Amount  \
# 1         824  ...              2017-07-14          456
# ...

# %%
## Extract Data.

# %%
data.to_csv("C:\\Users\\ckkapadiya74\\Downloads\\data1.csv" ,index=False)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 data.to_csv("C:\\Users\\ckkapadiya74\\Downloads\\data1.csv" ,index=False)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3720, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3709 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3711 formatter = DataFrameFormatter(
#    3712     frame=df,
# ...
